# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl 
data = pd.read_csv("//Users//sinchansuvarna//Downloads//space-mission-analysis.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df=pd.DataFrame(data)
print()
print('◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆')
print('◆                                               ◆')
print('◆  Welcome to the Universe at your fingertips!  ◆')
print('◆                                               ◆')
print('◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆ \n')
print('From the depths of space to the heart of the Milky Way, our project is your guide to the cosmos. \nBegin your exploration now and unlock the secrets of the universe. \nSpace mission launches encapsulate the spirit of human exploration, curiosity, and the quest for knowledge \nbeyond the confines of our home planet. \nIn this introduction, we will delve into the captivating world of space missions, exploring the details of these \nmissions they offer for scientific discovery and technological advancement.\n ')

def main_code():
    while True:
        print('1. View space mission records')
        print('Please choose from the following')
        print('Enter:\n 1 to view the records\n', 
              '2 to view successful missions\n',
              '3 to view failed missions\n',
              '4 to view active missions\n',
              '5 to view retired missions\n',
              '6 to view first n rows\n',
              '7 to view last n rows\n',
              '8 to view information of the dataframe\n',
              '9 to view the description of the dataframe\n',
              '10 to view information for each space agency\n',
              '11 to view the sorted records based on Company Name\n',
              '12 to view columns details\n',
              '13 to view extracted data from the records\n',
              '14 to view graphical representation of frequency vs day\n',
              '15 to add a column\n',
              '16 to add a row\n', 
              '17 to modify values of \'Status Rocket\' \n', 
              '18 to modify values of \'Status Mission\' \n', 
              '19 to delete column \'Detail\' \n', 
              '20 to delete a row \n', 
              '21 to exit')
        v = int(input('Enter category number: '))
        print('You have entered', v)
        print()
        if v == 1:
            print(df) #To view the records
        elif v == 2:
            print(df[df['Status Mission']=='Success']) #To view successful missions
        elif v == 3:
            print(df[df['Status Mission']=='Failure']) #To view failed missions
        elif v == 4:
            print(df[df['Status Rocket']=='StatusActive']) #To view active missions
        elif v == 5:
            print(df[df['Status Rocket']=='StatusRetired']) #To view retired missions
        elif v == 6:
            n1 = int(input('Please enter the number of rows to be viewed from the top: '))
            print(df.head(n1)) #To view first n rows
        elif v == 7:
            n2 = int(input('Please enter the number of rows to be viewed from the bottom: '))
            print(df.tail(n2)) #To view last n rows
        elif v == 8:
            print(df.info()) #information of records
        elif v == 9:
            print(df.describe()) #description of records
        elif v == 10:
            for a,b in df.iterrows():
                print('Row index:' ,a)
                print(b)
                print('﹌﹌﹌'*15) #To view details of each space agency
            print()
        elif v == 11:
            sort_df = df.sort_values('Company Name') #To view sorted records based on Company Name
            print(sort_df)
        elif v == 12:
            print(df.columns) #To view columns details
        elif v == 13:
            v1 = int(input('Enter:\n 1 for slicing values\n 2 to view the records in reverse order\n'))
            if v1 == 1:
                start = int(input('Enter start value ranging from 0-30: '))
                stop = int(input('Enter stop value ranging from 0-30: '))
                step = int(input('Enter step value ranging from 0-30: '))
                print(df[start:stop:step]) #Slicing values
            elif v1 == 2:
                print(df[::-1]) #displaying in reverse order
            else:
                print("Wrong Choice, please enter from the options")
        elif v == 14:
            #User can choose from three types of graph to view frequency vs day: Histogram, Line chart, Bar Chart
            g = input('Enter:\n 1 for Histogram\n 2 for Line Chart\n 3 for Bar Chart\n')
            g = int(g)
            if g == 1:
                x = df['Day']
                pl.hist(x, bins = 7, histtype = 'step', ec = 'm', label='Day')
                pl.xlabel('Day')
                pl.ylabel('Frequency')
                pl.legend(loc = 'upper right')
                pl.show()
            elif g == 2:
                counts = df['Day'].value_counts()
                x = counts.index
                y = counts.values
                pl.plot(x,y, color = 'teal', markeredgecolor='magenta', marker = 'D')
                pl.xlabel('Days')
                pl.ylabel('Frequency')
                pl.show()
            elif g == 3:
                counts = df['Day'].value_counts()
                x = counts.index
                y = counts.values
                pl.bar(x, y, width = 0.5, ec = 'g', label='Status', color = 'c')
                pl.xlabel('Days')
                pl.ylabel('Frequency')
                pl.show()
            else:
                print("Wrong Choice, please enter from the options")
        elif v == 15:
            # Adding column ‘Cost’
            print(df.assign(Cost=[34, 38, 21, 36, 37, 47, 25, 20, 45, 36, 24, 20, 49, 23, 22, 32, 21, 20, 23, 43, 21, 36, 39, 39, 41, 37, 41, 20, 37, 46]))
        elif v == 16:
            df.loc[30]=[31, 'Roscosmos', 'Site 31/6,Baikonur Cosmodrome, Kazakhstan', 'Wednesday', 'July 31, 2019', '12:10 UTC', 'Soyuz 2.1a l Progress MS- 12', 'StatusActive', 48.5, 'Success']
            print(df)  # adding row 31
        elif v == 17:
            #modified values of ‘Status Rocket'
            df['Status Rocket']=['StatusActive', 'StatusActive', 'StatusActive', 'StatusRetired' , 'StatusActive', 'StatusActive', 'StatusRetired', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusRetired', 'StatusActive', 'StatusRetired', 'StatusActive', 'StatusActive', 'StatusRetired', 'StatusActive', 'StatusRetired', 'StatusActive', 'StatusRetired', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusActive', 'StatusRetired', 'StatusActive']
            print(df)
        elif v == 18:
            #modified values of ‘Status Mission’
            df['Status Mission']=['Success', 'Success', 'Failure', 'Success', 'Success', 'Success', 'Failure', 'Success', 'Success', 'Success', 'Success', 'Failure', 'Success', 'Success', 'Success', 'Failure', 'Success', 'Success', 'Failure', 'Failure', 'Failure', 'Success', 'Success', 'Success', 'Success', 'Success', 'Success', 'Failure', 'Failure', 'Success']  
            print(df)
        elif v == 19:
            d1 = df.drop(['Detail'],axis=1)
            print(d1) #deletes column ‘Detail’
        elif v == 20:
            du = int(input('Enter the row sno to delete: '))
            d2 = df.drop([du]) #Deleting row
            print(d2)
        elif v == 21:
            print('Exiting')
            break
        else:
            print("Wrong Choice, please enter from the options")
            break

def login():
    print('Please choose from the following')
    main_code()

print('✧༺', "PLEASE LOGIN!", '༻✧')
x = ["P7538", "R6968", "S7188"]
y = input("Enter your ADMIN ID: ")
if y in x:
    if y == 'P7538':
        print("WELCOME Prachi!")
        login()
    elif y == 'R6968':
        print("WELCOME Riya!")
        login()
    elif y == 'S7188':
        print("WELCOME Sinchan!")
        login()
    else:
        print("!!ACCESS DENIED!!")
# Out:
# ◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆
# ◆                                               ◆
# ◆  Welcome to the Universe at your fingertips!  ◆
# ◆                                               ◆
# ◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆:*:◇:*:◆
#
# From the depths of space to the heart of the Milky Way, our project is your guide to the cosmos.
# Begin your exploration now and unlock the secrets of the universe.
# Space mission launches encapsulate the spirit of human exploration, curiosity, and the quest for knowledge
# beyond the confines of our home planet.
# In this introduction, we will delve into the captivating world of space missions, exploring the details of these
# missions they offer for scientific discovery and technological advancement.
#
# ✧༺ PLEASE LOGIN! ༻✧
# Enter your ADMIN ID: S7188
# WELCOME Sinchan!
# Please choose from the following
# 1. View space mission records
# Please choose from the following
# Enter:
#  1 to view the records
# ...

# %% [markdown]
# ##
